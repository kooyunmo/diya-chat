# %%
# !ls subtitles_html/
# Out:
# 500일의썸머.html
# Bruce_almighty.html
# Byzantium.html
# Darkest_Hour.html
# Deadpool.html
# Gladiator.html
# Interstellar.html
# Justice_League.html
# Love_Actually.html
# Now_you_see_me.html
# Prometheus.html
# endgame_sub.html
# wonder_woman.html
# 미_비포_유.html
# 더_리더_책_읽어주는_남자.html
# 람보.html
# 레옹.html
# 바울.html
# 베놈.html
# 코코.html
# 헐크.html
# 쏘우3.html
# 리얼_스틸.html
# 너의_이름은.html
# 메리_포핀스.html
# 하치_이야기.html
# 호빗_뜻밖의_여정.html
# 너의_췌장을_먹고싶어.html
# 센과_치히로의_행방불명.html
# 닥터_스트레인지.html
# 토르_라그라노크.html
# 다운폴.html
# 메멘토.html
# 몬테나.html
# 아바타.html
# 알라딘.html
# 애나벨.html
# 인셉션.html
# 컨저링.html
# 킹스맨.html
# 테이큰.html
# 패딩턴.html
# 월드워Z.html
# 천공의_성_라퓨타.html
# 마지막_황제.html
# 미녀와_야수.html
# 쇼생크_탈출.html
# 양들의_침묵.html
# 오만과_편견.html
# 제독의_연인.html
# 주먹왕_랄프2.html
# 라이프_오프_파이.html
# 쉐이프_오브_워터.html
# 노인을_위한_나라는_없다.html
# 벤자민_버튼_시간을_거꾸로_가다.html
# 명탐정_피카츄.html
# 샬롯의_거미줄.html
# 위대한_겟츠비.html
# 이웃집_토토로.html
# 퍼스트_어벤져.html
# 한니발_라이징.html
# 월터의_상상은_현실이_된다.html
# 신비한_동물사전.html
# 유주얼_서스펙트.html
# 킬러의_보디가드.html
# ...

# %%
from bs4 import BeautifulSoup

import numpy as np 
import pandas as pd
import os
import re

DATA_IN_PATH = './subtitles_html/'

print("file size : ")
for file in os.listdir(DATA_IN_PATH):
    if 'html' in file :
        print(file.ljust(30) + str(round(os.path.getsize(DATA_IN_PATH + file) / 1000000, 2)) + 'MB')
# Out:
# 파일 크기 :
# 셰익스피어_인_러브.html               0.08MB
# Darkest_Hour.html             0.19MB
# 명탐정_피카츄.html                  0.22MB
# 아이언맨2.html                    0.12MB
# 위대한_겟츠비.html                  0.23MB
# 인어공주.html                     0.11MB
# 킹스맨.html                      0.32MB
# 적벽대전.html                     0.1MB
# 반지의_제왕2.html           0.01MB
# 하치_이야기.html                   0.09MB
# 미드나잇_인_파리.html                0.18MB
# 샬롯의_거미줄.html                  0.13MB
# Gladiator.html                0.16MB
# 알라딘.html                      0.19MB
# 블랙스완.html                     0.1MB
# 람보.html                       0.13MB
# 한니발_라이징.html                  0.08MB
# 오만과_편견.html                   0.16MB
# 얼음왕국.html                     0.14MB
# 마지막_황제.html                   0.26MB
# 메멘토.html                      0.1MB
# 트와일라잇2.html                   0.31MB
# 해리포터와_불사조_기사단.html            0.3MB
# 레버넌트.html                     0.1MB
# 패딩턴.html                      0.14MB
# ...

# %%
file = "어바웃타임.html"

# %%
with open(DATA_IN_PATH + file, 'r') as f:
    html_string = f.read()

# %%
soup = BeautifulSoup(html_string)

# %%
html_string
# Out:
# '<SAMI>\n<HEAD>\n<TITLE></TITLE>\n<STYLE TYPE="text/css">\n<!--\nP { margin-left:16pt; margin-right:16pt; margin-bottom:16pt;\n    margin-top:16pt; font-size:18pt; text-align:center;\n    font-family:arial; font-weight:bold; color:#f0f0f0;\n    }\n.UNKNOWNCC { Name:Unknown; lang:en-US; SAMIType:CC; }\n-->\n</STYLE>\n</HEAD>\n<BODY>\n<SYNC Start=46000><P Class=UNKNOWNCC>\nsub2smi<br>\nDaikon Universe\n<SYNC Start=50760><P Class=UNKNOWNCC>\n어바웃 타임\n<SYNC Start=53433><P Class=UNKNOWNCC>&nbsp;\n<SYNC Start=54600><P Class=UNKNOWNCC>\n우리 가족이 좀 이상하다는 건 항상<br>알고 있었다, 우선 나부터 그렇다\n<SYNC Start=58639><P Class=UNKNOWNCC>&nbsp;\n<SYNC Start=59000><P Class=UNKNOWNCC>\n너무 길쭉하고 너무 빼빼하고<br>머리도 너무 오렌지 색이다\n<SYNC Start=62037><P Class=UNKNOWNCC>&nbsp;\n<SYNC Start=62560><P Class=UNKNOWNCC>\n우리 엄만 사랑스러운 분이었지만<br>보통 엄마들과는 다른 면이 많았다\n<SYNC Start=65028><P Class=UNKNOWNCC>&nbsp;\n<SYNC Start=65160><P Class=UNKNOWNCC>\n엄만 아주 독립적인 분이셨다\n<SYNC Start=66513><P Class=UNKNOWNCC>&nbsp;\n<SYNC Start=66600><P Class=UNK
# ...

# %%
html_string = html_string.replace('<br>', ' ')

# %%
conv_string = re.sub("\<.*?\>|&nbsp;|sub2smi", "", html_string)

# %%
conv_string
# Out:
# '\n\n\n\n<!--\nP { margin-left:16pt; margin-right:16pt; margin-bottom:16pt;\n    margin-top:16pt; font-size:18pt; text-align:center;\n    font-family:arial; font-weight:bold; color:#f0f0f0;\n    }\n.UNKNOWNCC { Name:Unknown; lang:en-US; SAMIType:CC; }\n-->\n\n\n\n\n \nDaikon Universe\n\n어바웃 타임\n\n\n우리 가족이 좀 이상하다는 건 항상 알고 있었다, 우선 나부터 그렇다\n\n\n너무 길쭉하고 너무 빼빼하고 머리도 너무 오렌지 색이다\n\n\n우리 엄만 사랑스러운 분이었지만 보통 엄마들과는 다른 면이 많았다\n\n\n엄만 아주 독립적인 분이셨다\n\n\n독특하면서 늘 바쁘고 냉철하셨다\n\n\n엄마의 패션 아이콘은 퀸이었다\n\n\n아빤 좀 더 평범하셨다 항상 시간이 남아도는 분이셨다\n\n\n50세 생신 때 대학에서 학생들 가르치는 걸 그만두면서\n\n\n이젠 얘기도 하고 나한테 탁구도 져주시면서\n\n\n여생을 여유롭게 사시게 됐다\n\n\n그리고 엄마의 동생 데스몬드 삼촌도 있다\n\n\n삼촌은 늘 흠잡을 데 없이 옷을 입는다 그렇게 차려입고\n\n\n별다른 일은 안 하신다\n\n\n삼촌은 아주 매력적이고 영리한 사람이었다\n\n\n항상 다른 생각을 하고 사는 분이셨지만 그게 뭔지 우린 결국 알아내지 못했다\n\n\n그리고 마지막으로 캐서린\n\n\n케이티, 킷캣이라고 부르기도 하는 내 여동생이다\n\n\n분별 있는 재킷과 헤어컷 가족들 사이에\n\n\n천상의 아이가 있는 거다\n\n\n요정 같은 눈과 보라색 티셔츠 항상 벗고 있는 발\n\n\n그때도 그랬지만 지금도 마찬가지다\n\n\n그 아인 세상에서 가장 근사한 존재다\n\n\n특별히 유별난 것 없이 전반적으로 행복한 어린 시절이었다\n\n\n내가 21살이 됐을 때까지
# ...

# %%
conv_string = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ,.?!\s]", "", conv_string)

# %%
conv_string
# Out:
# '\n\n\n\n!\n    \n      \n      \n    \n.     \n\n\n\n\n\n \n \n\n어바웃 타임\n\n\n우리 가족이 좀 이상하다는 건 항상 알고 있었다, 우선 나부터 그렇다\n\n\n너무 길쭉하고 너무 빼빼하고 머리도 너무 오렌지 색이다\n\n\n우리 엄만 사랑스러운 분이었지만 보통 엄마들과는 다른 면이 많았다\n\n\n엄만 아주 독립적인 분이셨다\n\n\n독특하면서 늘 바쁘고 냉철하셨다\n\n\n엄마의 패션 아이콘은 퀸이었다\n\n\n아빤 좀 더 평범하셨다 항상 시간이 남아도는 분이셨다\n\n\n세 생신 때 대학에서 학생들 가르치는 걸 그만두면서\n\n\n이젠 얘기도 하고 나한테 탁구도 져주시면서\n\n\n여생을 여유롭게 사시게 됐다\n\n\n그리고 엄마의 동생 데스몬드 삼촌도 있다\n\n\n삼촌은 늘 흠잡을 데 없이 옷을 입는다 그렇게 차려입고\n\n\n별다른 일은 안 하신다\n\n\n삼촌은 아주 매력적이고 영리한 사람이었다\n\n\n항상 다른 생각을 하고 사는 분이셨지만 그게 뭔지 우린 결국 알아내지 못했다\n\n\n그리고 마지막으로 캐서린\n\n\n케이티, 킷캣이라고 부르기도 하는 내 여동생이다\n\n\n분별 있는 재킷과 헤어컷 가족들 사이에\n\n\n천상의 아이가 있는 거다\n\n\n요정 같은 눈과 보라색 티셔츠 항상 벗고 있는 발\n\n\n그때도 그랬지만 지금도 마찬가지다\n\n\n그 아인 세상에서 가장 근사한 존재다\n\n\n특별히 유별난 것 없이 전반적으로 행복한 어린 시절이었다\n\n\n내가 살이 됐을 때까지도 우린 매일 해변에서 차를 마셨다\n\n\n물수제비도 뜨고 샌드위치도 먹으면서\n\n\n여름, 겨울 날씨와 상관없이\n\n\n금요일 밤마다 영화를 봤다\n\n\n날씨와 상관없이\n\n\n그리고 일 년에 한 번 끔찍한 새해 전야제 파티가 있다\n\n\n하나 더 마실래\n\n\n정말 멋지시네요\n\n\n난 케이티예요 내가 마시는 게 뭐예요?\n\n\n이거 아주 비싼 거예요\n\n\n 건배  건배\n\n\
# ...

# %%
conv_string = conv_string.split(sep='\n')

# %%
conv_string
# Out:
# ['',
#  '',
#  '',
#  '',
#  '!',
#  '    ',
#  '      ',
#  '      ',
#  '    ',
#  '.     ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' ',
#  ' ',
#  '',
#  '어바웃 타임',
#  '',
#  '',
#  '우리 가족이 좀 이상하다는 건 항상 알고 있었다, 우선 나부터 그렇다',
#  '',
#  '',
#  '너무 길쭉하고 너무 빼빼하고 머리도 너무 오렌지 색이다',
#  '',
#  '',
#  '우리 엄만 사랑스러운 분이었지만 보통 엄마들과는 다른 면이 많았다',
#  '',
#  '',
#  '엄만 아주 독립적인 분이셨다',
#  '',
#  '',
#  '독특하면서 늘 바쁘고 냉철하셨다',
#  '',
#  '',
#  '엄마의 패션 아이콘은 퀸이었다',
#  '',
#  '',
#  '아빤 좀 더 평범하셨다 항상 시간이 남아도는 분이셨다',
#  '',
#  '',
#  '세 생신 때 대학에서 학생들 가르치는 걸 그만두면서',
#  '',
#  '',
#  '이젠 얘기도 하고 나한테 탁구도 져주시면서',
#  '',
#  '',
#  '여생을 여유롭게 사시게 됐다',
#  '',
#  '',
#  '그리고 엄마의 동생 데스몬드 삼촌도 있다',
#  '',
#  '',
#  '삼촌은 늘 흠잡을 데 없이 옷을 입는다 그렇게 차려입고',
#  '',
#  '',
#  '별다른 일은 안 하신다',
#  '',
#  '',
#  '삼촌은 아주 매력적이고 영리한 사람이었다',
#  '',
#  '',
#  '항상 다른 생각을 하고 사는 분이셨지만 그게 뭔지 우린 결국 알아내지 못했다',
#  '',
#  '',
#  '그리고 마지막으로 캐서린',
#  '',
#  '',
#  '케이티, 킷캣이라고 부르기도 하는 내 여동생이다',
#  '',
#  '',
#  '분별 있는 재킷과 헤어컷 가족들 사이에',
#  '',
#  '',
# ...

# %%
str_list = list(filter(None, conv_string))

# %%
str_list
# Out:
# ['!',
#  '    ',
#  '      ',
#  '      ',
#  '    ',
#  '.     ',
#  ' ',
#  ' ',
#  '어바웃 타임',
#  '우리 가족이 좀 이상하다는 건 항상 알고 있었다, 우선 나부터 그렇다',
#  '너무 길쭉하고 너무 빼빼하고 머리도 너무 오렌지 색이다',
#  '우리 엄만 사랑스러운 분이었지만 보통 엄마들과는 다른 면이 많았다',
#  '엄만 아주 독립적인 분이셨다',
#  '독특하면서 늘 바쁘고 냉철하셨다',
#  '엄마의 패션 아이콘은 퀸이었다',
#  '아빤 좀 더 평범하셨다 항상 시간이 남아도는 분이셨다',
#  '세 생신 때 대학에서 학생들 가르치는 걸 그만두면서',
#  '이젠 얘기도 하고 나한테 탁구도 져주시면서',
#  '여생을 여유롭게 사시게 됐다',
#  '그리고 엄마의 동생 데스몬드 삼촌도 있다',
#  '삼촌은 늘 흠잡을 데 없이 옷을 입는다 그렇게 차려입고',
#  '별다른 일은 안 하신다',
#  '삼촌은 아주 매력적이고 영리한 사람이었다',
#  '항상 다른 생각을 하고 사는 분이셨지만 그게 뭔지 우린 결국 알아내지 못했다',
#  '그리고 마지막으로 캐서린',
#  '케이티, 킷캣이라고 부르기도 하는 내 여동생이다',
#  '분별 있는 재킷과 헤어컷 가족들 사이에',
#  '천상의 아이가 있는 거다',
#  '요정 같은 눈과 보라색 티셔츠 항상 벗고 있는 발',
#  '그때도 그랬지만 지금도 마찬가지다',
#  '그 아인 세상에서 가장 근사한 존재다',
#  '특별히 유별난 것 없이 전반적으로 행복한 어린 시절이었다',
#  '내가 살이 됐을 때까지도 우린 매일 해변에서 차를 마셨다',
#  '물수제비도 뜨고 샌드위치도 먹으면서',
#  '여름, 겨울 날씨와 상관없이',
#  '금요일 밤마다 영화를 봤다',
#  '날씨와 상관없이',
#  '그리고 일 년에 한 번 끔찍한 새해 전야제 파티가 있다',
#  '하나 더 마실래',
#  '정말 멋지시네요',
# ...

# %%
str_list[len(str_list)-5:]
# Out:
# ['이 멋진 여행을 즐기는 것뿐이다', '그래, 그래...', '그래, 그럼 그때 보자', '안녕', '나중에 봐']

# %%
with open('./subtitles_html/conv/' + file, 'w+') as f:
    for item in str_list:
        f.write("%s\n" % item)

# %%
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd
import os
import re
from tqdm import tqdm

DATA_IN_PATH = './subtitles_html/'
DATA_OUT_PATH = './subtitles_html/conv/'

print("file name".ljust(30) + "size")
for file in tqdm(os.listdir(DATA_IN_PATH)):
    if 'html' in file:
        print(file.ljust(
            30) + str(round(os.path.getsize(DATA_IN_PATH + file) / 1000000, 2)) + 'MB')

    try:
        with open(os.path.join(DATA_IN_PATH, file), 'r') as f:
            html_string = f.read()

        soup = BeautifulSoup(html_string)

        html_string = html_string.replace('<br>', ' ')

        conv_string = re.sub("\<.*?\>|&nbsp;|sub2smi", "", html_string)
        conv_string = re.sub("[^가-힣ㄱ-ㅎㅏ-ㅣ,.?!\s]", "", conv_string)

        conv_string = conv_string.split(sep='\n')

        str_list = list(filter(None, conv_string))

        with open(os.path.join(DATA_OUT_PATH, file), 'w+') as f:
            for item in str_list:
                f.write("%s\n" % item)

    except UnicodeDecodeError:
        print("This file is not 'utf-8' format. Skip this file.")
        pass

    except IsADirectoryError:
        pass
# Out:
#   1%|          | 1/101 [00:00<00:11,  8.54it/s]
# file name                     size
# 셰익스피어_인_러브.html               0.08MB
# Darkest_Hour.html             0.19MB
#   3%|▎         | 3/101 [00:00<00:14,  6.62it/s]
# 명탐정_피카츄.html                  0.22MB
# 아이언맨2.html                    0.12MB
#   4%|▍         | 4/101 [00:00<00:16,  5.76it/s]
# 위대한_겟츠비.html                  0.23MB
#   6%|▌         | 6/101 [00:01<00:17,  5.48it/s]
# 인어공주.html                     0.11MB
# 킹스맨.html                      0.32MB
#   7%|▋         | 7/101 [00:01<00:21,  4.41it/s]
# 적벽대전.html                     0.1MB
#  10%|▉         | 10/101 [00:01<00:16,  5.48it/s]
# 반지의_제왕2.html           0.01MB
# 하치_이야기.html                   0.09MB
# 미드나잇_인_파리.html                0.18MB
#  12%|█▏        | 12/101 [00:02<00:15,  5.92it/s]
# 샬롯의_거미줄.html                  0.13MB
# Gladiator.html                0.16MB
#  13%|█▎        | 13/101 [00:02<00:17,  4.91it/s]
# 알라딘.html                      0.19MB
# ...
